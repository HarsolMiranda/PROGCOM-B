# %%
# Clase padre
class Vehiculo:
    def __init__(self, marca, modelo):
        self.marca = marca
        self.modelo = modelo

    def encender(self):
        print(f"El {self.marca} {self.modelo} está encendido.")

# Clase hija
class Carro(Vehiculo):
    def abrir_puertas(self):
        print(f"El {self.marca} {self.modelo} ha abierto las puertas.")

# Uso
mi_carro = Carro("Toyota", "Corolla")
mi_carro.encender()        # Heredado de Vehiculo
mi_carro.abrir_puertas()   # Propio de Carro

# %%
# Clase base
class Personaje:
    def __init__(self, nombre, poder):
        self.nombre = nombre
        self.poder = poder

    def presentarse(self):
        print(f"Soy {self.nombre} y tengo un poder de {self.poder}.")

    def atacar(self):
        print(f"{self.nombre} lanza un ataque básico.")

# Subclase Saiyajin
class Saiyajin(Personaje):
    def transformar(self):
        print(f"{self.nombre} se transforma en Super Saiyajin 💛")

    def atacar(self):
        print(f"{self.nombre} lanza un Kamehameha 🔥")

# Subclase Namekusein
class Namekusein(Personaje):
    def regenerar(self):
        print(f"{self.nombre} regenera una parte de su cuerpo 🧪")

    def atacar(self):
        print(f"{self.nombre} lanza una onda expansiva verde 💚")

# Subclase Humano
class Humano(Personaje):
    def entrenar(self):
        print(f"{self.nombre} mejora su poder con entrenamiento 🏋️")

    def atacar(self):
        print(f"{self.nombre} lanza un ataque con tecnología ⚙️")

# Crear instancias
goku = Saiyajin("Goku", 9000)
piccolo = Namekusein("Piccolo", 7500)
krilin = Humano("Krilin", 3000)

# Usar métodos
goku.presentarse()
goku.transformar()
goku.atacar()

piccolo.presentarse()
piccolo.regenerar()
piccolo.atacar()

krilin.presentarse()
krilin.entrenar()
krilin.atacar()

# %%
# Clase base para animales acuáticos
class AnimalAcuatico:
    def __init__(self, nombre):
        self.nombre = nombre

    def nadar(self):
        print(f"El {self.nombre} está nadando.")

    def respirar(self):
        print(f"El {self.nombre} respira bajo el agua.")

# Subclase Pez
class Pez(AnimalAcuatico):
    def __init__(self, nombre, tipo_escamas):
        super().__init__(nombre)
        self.tipo_escamas = tipo_escamas

    def mostrar_escamas(self):
        print(f"El {self.nombre} tiene escamas de tipo {self.tipo_escamas}.")

    def respirar(self):
        print(f"El {self.nombre} respira con branquias.")

# Subclase Delfín
class Delfin(AnimalAcuatico):
    def __init__(self, nombre):
        super().__init__(nombre)

    def comunicarse(self):
        print(f"El {self.nombre} emite sonidos para comunicarse.")

    def respirar(self):
        print(f"El {self.nombre} respira aire con su espiráculo.")

# Subclase Ballena
class Ballena(AnimalAcuatico):
    def __init__(self, nombre):
        super().__init__(nombre)

    def sumergirse(self):
        print(f"La {self.nombre} se sumerge profundamente.")

    def respirar(self):
        print(f"La {self.nombre} respira aire con su espiráculo.")


# Crear instancias
pez_payaso = Pez("Pez Payaso", "cicloides")
delfin = Delfin("Flipper")
ballena_azul = Ballena("Ballena Azul")

# Usar métodos
pez_payaso.nadar()
pez_payaso.respirar()
pez_payaso.mostrar_escamas()

delfin.nadar()
delfin.respirar()
delfin.comunicarse()

ballena_azul.nadar()
ballena_azul.respirar()
ballena_azul.sumergirse()

# %%
class Persona:
    def __init__(self, nombre, edad, estado_fisico):
        self.nombre = nombre
        self.edad = edad
        self.estado_fisico = estado_fisico

    def presentarse(self):
        print(f"Soy {self.nombre}, tengo {self.edad} años, mi estado físico es '{self.estado_fisico}'.")

    def atacar(self):
        print(f"{self.nombre} realiza un ataque básico.")

class Guerrero(Persona):
    def __init__(self, nombre, edad, estado_fisico):
        super().__init__(nombre, edad, estado_fisico)

    def presentarse(self):
        print(f"Soy {self.nombre}, un guerrero de {self.edad} años con estado físico '{self.estado_fisico}'.")

    def atacar(self):
        print(f"{self.nombre} ataca con su espada.")

class Soldado(Persona):
    def __init__(self, nombre, edad, estado_fisico):
        super().__init__(nombre, edad, estado_fisico)

    def presentarse(self):
        print(f"Soy {self.nombre}, un soldado de {self.edad} años con estado físico '{self.estado_fisico}'.")

    def atacar(self):
        print(f"{self.nombre} dispara su arma de balas.")

# Prueba
carlos = Guerrero("Carlos", 35, "atlético")
david = Soldado("David", 28, "resistente")

carlos.presentarse()
carlos.atacar()

david.presentarse()
david.atacar()

# %%
# Clase base
class Persona:
    def __init__(self, nombre, edad):
        self.nombre = nombre
        self.edad = edad

    def saludar(self):
        return f"Hola, soy {self.nombre}, tengo {self.edad} años."

# Clase hija: Estudiante
class Estudiante(Persona):
    def __init__(self, nombre, edad, carrera, universidad, estudios_previos):
        super().__init__(nombre, edad)
        self.carrera = carrera
        self.universidad = universidad
        self.estudios_previos = estudios_previos

    def saludar(self):
        return (
            f"Hola, soy {self.nombre}, tengo {self.edad} años, estudio {self.carrera} "
            f"en la universidad {self.universidad}, y antes estudié {self.estudios_previos}."
        )

# Clase hija: Profesor
class Profesor(Persona):
    def __init__(self, nombre, edad, materia, universidad, titulo):
        super().__init__(nombre, edad)
        self.materia = materia
        self.universidad = universidad
        self.titulo = titulo

    def saludar(self):
        return (
            f"Hola, soy el profe {self.nombre}, tengo {self.edad} años, enseño {self.materia} "
            f"en la universidad {self.universidad}, y tengo un título en {self.titulo}."
        )

# Ejemplo de uso
personas = [
    Estudiante("Laura", 21, "Ingeniería", "Universidad Nacional", "Bachillerato Técnico"),
    Profesor("Carlos", 45, "Matemáticas", "Universidad Industrial de Santander", "Educación Matemática")
]

for p in personas:
    print(p.saludar())

# %%
# Clase base
class Carta:
    def __init__(self, nombre, puntos_vida, daño):
        self.nombre = nombre
        self.puntos_vida = puntos_vida
        self.daño = daño

    def mostrar_info(self):
        return f"{self.nombre}: Vida {self.puntos_vida}, Daño {self.daño}"

    def usar(self):
        return f"{self.nombre} ha sido desplegada."

# Clase derivada: Tropa
class Tropa(Carta):
    def atacar(self):
        return f"{self.nombre} ataca al enemigo causando {self.daño} de daño."

# Clase derivada: Hechizo
class Hechizo(Carta):
    def lanzar(self):
        return f"{self.nombre} se lanza causando {self.daño} de daño en área."

# Clase derivada: Estructura
class Estructura(Carta):
    def defender(self):
        return f"{self.nombre} defiende la zona con {self.puntos_vida} puntos de vida."

# Ejemplo de uso
valquiria = Tropa("Valquiria", 1200, 150)
bola_de_fuego = Hechizo("Bola de Fuego", 0, 250)
torre_bombardera = Estructura("Torre Bombardera", 1500, 100)

print(valquiria.mostrar_info())
print(valquiria.usar())
print(valquiria.atacar())

print(bola_de_fuego.mostrar_info())
print(bola_de_fuego.usar())
print(bola_de_fuego.lanzar())

print(torre_bombardera.mostrar_info())
print(torre_bombardera.usar())
print(torre_bombardera.defender())
